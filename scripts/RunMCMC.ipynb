# %%
import papermill as pm

# List of input arguments
usernames = ['u','B','g','V','r','i','Y','J','H']
#usernames = ['u']
for name in usernames:
    output_path = f'output_{name}.ipynb'
    
    print(f"Running notebook for {name}")
    pm.execute_notebook(
        'H0_colormethod.ipynb',   # Input notebook
        output_path,           # Output notebook
        parameters={'usernames': name}
    )
# Out:
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for u
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:22<00:00,  4.36s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for B
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:25<00:00,  4.50s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for g
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:23<00:00,  4.40s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for V
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:25<00:00,  4.52s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for r
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:24<00:00,  4.43s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for i
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:24<00:00,  4.43s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for Y
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:22<00:00,  4.32s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for J
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:21<00:00,  4.29s/cell]
# Passed unknown parameter: usernames
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for H
# Executing: 100%|██████████████████████████████████████████████████████████████████████████| 19/19 [01:21<00:00,  4.30s/cell]

# %%
import os
os.system('say "your program has finished."')
# Out:
# 0
