# %%
import papermill as pm

# List of input arguments
usernames = ['u','B','g','V','r','i','Y','J','H']

for name in usernames:
    output_path = f'output_{name}.ipynb'
    
    print(f"Running notebook for {name}")
    pm.execute_notebook(
        'Mark_H0_tripp.ipynb',   # Input notebook
        output_path,           # Output notebook
        parameters={'username': name}
    )
# Out:
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for u
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:57<00:00,  6.54s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for B
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:59<00:00,  6.65s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for g
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:57<00:00,  6.50s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for V
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:55<00:00,  6.39s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for r
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:54<00:00,  6.39s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for i
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:53<00:00,  6.30s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for Y
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:56<00:00,  6.48s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for J
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:54<00:00,  6.35s/cell]
# Passed unknown parameter: username
# Input notebook does not contain a cell with tag 'parameters'
# Running notebook for H
# Executing: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 18/18 [01:56<00:00,  6.49s/cell]

# %%
import os
os.system('say "your program has finished."')
# Out:
# 0
